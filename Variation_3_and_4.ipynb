# %% [markdown]
# # Covid-19 Auto-Detection using Deep Learning - Rohit Bhalerao ( November 2021 )

# %% [markdown]
# ## Variation # 03:
#
# 1. Class Imbalance : Yes ( Number of Covid images : 600 , Number of Non-Covid images : 1500 )
#
# 2. Image Augmentation : Yes
#
# 3. Noise Removal from images : No

# %% [markdown]
# **Connect to Google Drive to access Dataset**

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Dec  3 10:29:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/COVID_Detection'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/COVID_Detection

# %% [markdown]
# **Import all dependencies**

# %%
from __future__ import print_function, division
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications import EfficientNetB7

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import cv2
from glob import glob
import cv2 
from skimage import transform as tf

# %% [markdown]
# **Define Few Parameters**

# %%
#define parameters
IMAGE_SIZE = [224, 224]
epochs = 30
batch_size = 32
covid_path = 'data/COVID'
noncovid_path = 'data/NORMAL'

# Use glob to grab images from path .jpg or jpeg
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

count_orig_covid_img_for_model = 600
count_normal_img_for_model = 1500

# %%
# Understand the number of images in covid_files folder
len(covid_files)
# Out:
# 4152

# %%
# understand the number images in Non Covid files folder
len(noncovid_files)
# Out:
# 10860

# %% [markdown]
# **Fetch Images and Class Labels from Files (This might take a while)**

# %%
# Preparing Labels
covid_labels = []
noncovid_labels = []
covid_images=[]
noncovid_images=[]

# Covid Images
for i in range(count_orig_covid_img_for_model):
  #if i%10==0:
    #print('i:',i)
  image = cv2.imread(covid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  covid_images.append(image)
  covid_labels.append('COVID')


# Normal Images
for j in range(count_normal_img_for_model): 
  #if j%10==0:
    #print('j:',j)
  image = cv2.imread(noncovid_files[j])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('NonCOVID')

# %% [markdown]
# Visualize First 40 Images from Data set

# %%
# look at few images
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()

# %%
#plot_images(covid_images, 'Positive COVID-19 Chest X-ray')
#plot_images(gauss_noise_removed_images, 'Gaussian Noise Removed : Positive COVID-19 Chest X-ray')
#plot_images(median_noise_removed_images, 'Median Noise Removed : Positive COVID-19 Chest X-ray')
#plot_images(left_shear_images, 'Left Shear Images : Positive COVID-19 Chest X-ray')
#plot_images(right_shear_images, 'Right Shear Images : Positive COVID-19 Chest X-ray')
#plot_images(anticlock_rot_images, 'Anticlock Rotated Images : Positive COVID-19 Chest X-ray')
#plot_images(clock_rot_images, 'clock Rotated Images : Positive COVID-19 Chest X-ray')
#plot_images(noncovid_images, 'Negative COVID-19 Chest X-ray')

# %% [markdown]
# **Normalization**

# %% [markdown]
# Model takes images in the form of array of pixels. Hence convert into array and normalize

# %%
# normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# Normalizing image inputs: Data normalization is an important step which ensures that each input parameter (pixel, in this case) has a similar data distribution. 
# This makes convergence faster while training the network. Data normalization is done by subtracting the mean from each pixel and then dividing the result by the standard deviation. 
# The distribution of such data would resemble a Gaussian curve centered at zero. 
# For image inputs we need the pixel numbers to be positive, so we might choose to scale the normalized data in the range [0,1] or [0, 255].
# https://becominghuman.ai/image-data-pre-processing-for-neural-networks-498289068258

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# **Visualize a few images from Training and Test sets**

# %%
# plot_images(covid_x_train, 'X_train')

# %%
# plot_images(covid_x_test, 'X_test')

# %% [markdown]
# # Variation # 3
# # Model #1 : Xception
# ## Experiment #11

# %%
xception = Xception(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = xception.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=xception.input, outputs=outputs)

for layer in xception.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 4s 0us/step
# 83697664/83683744 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_1[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 14, 14, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 14, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 7, 7, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 7, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  flatten (Flatten)              (None, 100352)       0           ['block14_sepconv2_act[0][0]']
#
#  dropout (Dropout)              (None, 100352)       0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 2)            200706      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 21,062,186
# Trainable params: 200,706
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# **Images Augmentation**

# %%
# https://www.analyticsvidhya.com/blog/2020/08/image-augmentation-on-the-fly-using-keras-imagedatagenerator/

# ImageDataGenerator class has the argument height_shift_range for a vertical shift of image and width_shift_range for a horizontal shift of image. 
# If the value is a float number, that would indicate the percentage of width or height of the image to shift. 
# Otherwise, if it is an integer value then simply the width or height are shifted by those many pixel values.

# ImageDataGenerator class allows you to randomly rotate images through any degree between 0 and 360 by providing an integer value in the rotation_range argument.
# When the image is rotated, some pixels will move outside the image and leave an empty area that needs to be filled in. 
# You can fill this in different ways like a constant value or nearest pixel values, etc. 
# This is specified in the fill_mode argument and the default value is “nearest” which simply replaces the empty area with the nearest pixel values.

# No Augmentation to the images

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %% [markdown]
# **Training the model**

# %%
# https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
# save the current model ( if better than previous) and go to next epoch and repeat until the end

from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-11-Xception-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 1.3221 - accuracy: 0.8577
# Epoch 00001: val_accuracy improved from -inf to 0.92619, saving model to Experiment-11-Xception-model-epoch-01-val-accuracy:-0.9262.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 52/52 [==============================] - 27s 333ms/step - loss: 1.3221 - accuracy: 0.8577 - val_loss: 0.3627 - val_accuracy: 0.9262
# Epoch 2/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.9137
# Epoch 00002: val_accuracy did not improve from 0.92619
# 52/52 [==============================] - 16s 309ms/step - loss: 0.4915 - accuracy: 0.9137 - val_loss: 0.4894 - val_accuracy: 0.8786
# Epoch 3/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.9292
# Epoch 00003: val_accuracy improved from 0.92619 to 0.94286, saving model to Experiment-11-Xception-model-epoch-03-val-accuracy:-0.9429.h5
# 52/52 [==============================] - 17s 316ms/step - loss: 0.3514 - accuracy: 0.9292 - val_loss: 0.3520 - val_accuracy: 0.9429
# Epoch 4/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.9452
# Epoch 00004: val_accuracy did not improve from 0.94286
# 52/52 [==============================] - 16s 303ms/step - loss: 0.2745 - accuracy: 0.9452 - val_loss: 0.2726 - val_accuracy: 0.9405
# Epoch 5/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3143 - accuracy: 0.9393
# Epoch 00005: val_accuracy did not improve from 0.94286
# 52/52 [==============================] - 16s 306ms/step - loss: 0.3143 - accuracy: 0.9393 - val_loss: 0.7600 - val_accuracy: 0.8952
# Epoch 6/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4016 - accuracy: 0.9339
# Epoch 00006: val_accuracy did not improve from 0.94286
# 52/52 [==============================] - 16s 308ms/step - loss: 0.4016 - accuracy: 0.9339 - val_loss: 0.5919 - val_accuracy: 0.9238
# Epoch 7/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4612 - accuracy: 0.9375
# Epoch 00007: val_accuracy did not improve from 0.94286
# 52/52 [==============================] - 16s 307ms/step - loss: 0.4612 - accuracy: 0.9375 - val_loss: 0.8549 - val_accuracy: 0.9095
# Epoch 8/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3298 - accuracy: 0.9458
# Epoch 00008: val_accuracy did not improve from 0.94286
# 52/52 [==============================] - 16s 306ms/step - loss: 0.3298 - accuracy: 0.9458 - val_loss: 0.4595 - val_accuracy: 0.9286
# Epoch 9/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3219 - accuracy: 0.9482
# Epoch 00009: val_accuracy did not improve from 0.94286
# 52/52 [==============================] - 16s 303ms/step - loss: 0.3219 - accuracy: 0.9482 - val_loss: 0.6182 - val_accuracy: 0.9238
# Epoch 10/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.9589
# Epoch 00010: val_accuracy improved from 0.94286 to 0.94524, saving model to Experiment-11-Xception-model-epoch-10-val-accuracy:-0.9452.h5
# 52/52 [==============================] - 17s 314ms/step - loss: 0.2734 - accuracy: 0.9589 - val_loss: 0.3818 - val_accuracy: 0.9452
# Epoch 11/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9619
# Epoch 00011: val_accuracy improved from 0.94524 to 0.94762, saving model to Experiment-11-Xception-model-epoch-11-val-accuracy:-0.9476.h5
# 52/52 [==============================] - 17s 319ms/step - loss: 0.2222 - accuracy: 0.9619 - val_loss: 0.4409 - val_accuracy: 0.9476
# Epoch 12/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2325 - accuracy: 0.9589
# Epoch 00012: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 310ms/step - loss: 0.2325 - accuracy: 0.9589 - val_loss: 0.4063 - val_accuracy: 0.9405
# Epoch 13/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9643
# Epoch 00013: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 309ms/step - loss: 0.2137 - accuracy: 0.9643 - val_loss: 0.5257 - val_accuracy: 0.9405
# Epoch 14/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9601
# Epoch 00014: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 304ms/step - loss: 0.2058 - accuracy: 0.9601 - val_loss: 0.6178 - val_accuracy: 0.9262
# Epoch 15/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.9548
# Epoch 00015: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 306ms/step - loss: 0.3607 - accuracy: 0.9548 - val_loss: 0.6979 - val_accuracy: 0.9071
# Epoch 16/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.9280
# Epoch 00016: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 305ms/step - loss: 0.6807 - accuracy: 0.9280 - val_loss: 1.1140 - val_accuracy: 0.9190
# Epoch 17/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3615 - accuracy: 0.9565
# Epoch 00017: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 308ms/step - loss: 0.3615 - accuracy: 0.9565 - val_loss: 0.5899 - val_accuracy: 0.9452
# Epoch 18/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9690
# Epoch 00018: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 309ms/step - loss: 0.2345 - accuracy: 0.9690 - val_loss: 0.6243 - val_accuracy: 0.9381
# Epoch 19/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2321 - accuracy: 0.9607
# Epoch 00019: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 305ms/step - loss: 0.2321 - accuracy: 0.9607 - val_loss: 0.5150 - val_accuracy: 0.9357
# Epoch 20/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9690
# Epoch 00020: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 305ms/step - loss: 0.1706 - accuracy: 0.9690 - val_loss: 0.5355 - val_accuracy: 0.9381
# Epoch 21/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9732
# Epoch 00021: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 308ms/step - loss: 0.1876 - accuracy: 0.9732 - val_loss: 0.4848 - val_accuracy: 0.9405
# Epoch 22/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9679
# Epoch 00022: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 309ms/step - loss: 0.2180 - accuracy: 0.9679 - val_loss: 0.6073 - val_accuracy: 0.9310
# Epoch 23/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.9631
# Epoch 00023: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 306ms/step - loss: 0.3003 - accuracy: 0.9631 - val_loss: 0.5746 - val_accuracy: 0.9452
# Epoch 24/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.9637
# Epoch 00024: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 306ms/step - loss: 0.2730 - accuracy: 0.9637 - val_loss: 0.4899 - val_accuracy: 0.9381
# Epoch 25/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4799 - accuracy: 0.9500
# Epoch 00025: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 306ms/step - loss: 0.4799 - accuracy: 0.9500 - val_loss: 0.6736 - val_accuracy: 0.9310
# Epoch 26/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9714
# Epoch 00026: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 309ms/step - loss: 0.2075 - accuracy: 0.9714 - val_loss: 0.6649 - val_accuracy: 0.9310
# Epoch 27/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9661
# Epoch 00027: val_accuracy did not improve from 0.94762
# 52/52 [==============================] - 16s 308ms/step - loss: 0.2689 - accuracy: 0.9661 - val_loss: 0.6819 - val_accuracy: 0.9357
# Epoch 28/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9738
# Epoch 00028: val_accuracy improved from 0.94762 to 0.95000, saving model to Experiment-11-Xception-model-epoch-28-val-accuracy:-0.9500.h5
# 52/52 [==============================] - 17s 316ms/step - loss: 0.2013 - accuracy: 0.9738 - val_loss: 0.5532 - val_accuracy: 0.9500
# Epoch 29/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.9631
# Epoch 00029: val_accuracy did not improve from 0.95000
# 52/52 [==============================] - 16s 310ms/step - loss: 0.2619 - accuracy: 0.9631 - val_loss: 0.4824 - val_accuracy: 0.9381
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9750
# Epoch 00030: val_accuracy did not improve from 0.95000
# 52/52 [==============================] - 16s 305ms/step - loss: 0.2219 - accuracy: 0.9750 - val_loss: 0.3884 - val_accuracy: 0.9500

# %%
# Load best model for making prediction and plotting the statistics

model = load_model('Experiment-11-Xception-model-epoch-28-val-accuracy:-0.9500.h5')

# %% [markdown]
# ** Making and Visulaizing First 10 predictions**

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
    plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
    plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
    plt.imshow(X_test[index])
    plt.show()

# %% [markdown]
# Convert to Binary classes

# %%
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# **Plot ROC Curve, Confusion Matrix, Classification Report, Accuracy and Loss Plots **

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Testing'])
#plt.savefig('Experiment_09_xception_accuracy.png')
plt.show()
plt.figure(figsize=(6,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Testing'])
#plt.savefig('Experiment_09_xception_loss.png')
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92       120
#            1       0.98      0.95      0.96       300
#
#     accuracy                           0.95       420
#    macro avg       0.93      0.95      0.94       420
# weighted avg       0.95      0.95      0.95       420

# %% [markdown]
# ## Variation #3
# ## Model #2 : InceptionV3
# ## Experiment #12

# %%
inception = InceptionV3(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = inception.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=inception.input, outputs=outputs)

for layer in inception.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 3s 0us/step
# 87924736/87910968 [==============================] - 3s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 111, 111, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 111, 111, 32  96         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  activation (Activation)        (None, 111, 111, 32  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 109, 109, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 109, 109, 32  96         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 109, 109, 32  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 109, 109, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 109, 109, 64  192        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 109, 109, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['activation_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 54, 54, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 54, 54, 80)  240         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 54, 54, 80)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 52, 52, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 52, 52, 192)  576        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 52, 52, 192)  0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 25, 25, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 25, 25, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 25, 25, 48)  144         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 25, 25, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 25, 25, 48)   0           ['batch_normalization_10[0][0]']
#
#  activation_9 (Activation)      (None, 25, 25, 96)   0           ['batch_normalization_13[0][0]']
#
#  average_pooling2d (AveragePool  (None, 25, 25, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_9 (Conv2D)              (None, 25, 25, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 25, 25, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 25, 25, 64)  192         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 25, 25, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 25, 25, 96)  288         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 25, 25, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_9[0][0]']
#
#  activation_7 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_11[0][0]']
#
#  activation_10 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_14[0][0]']
#
#  activation_11 (Activation)     (None, 25, 25, 32)   0           ['batch_normalization_15[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 25, 25, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 25, 25, 48)  144         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 25, 25, 96)  288         ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_17[0][0]']
#
#  activation_16 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_20[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_16 (Conv2D)             (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 25, 25, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 25, 25, 64)  192         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 25, 25, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 25, 25, 96)  288         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 25, 25, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_16[0][0]']
#
#  activation_14 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_18[0][0]']
#
#  activation_17 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_21[0][0]']
#
#  activation_18 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_22[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 25, 25, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_26[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 25, 25, 48)  144         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 25, 25, 96)  288         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 25, 25, 48)   0           ['batch_normalization_24[0][0]']
#
#  activation_23 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_27[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 25, 25, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 25, 25, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 25, 25, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 25, 25, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 25, 25, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 25, 25, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 25, 25, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_23[0][0]']
#
#  activation_21 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_25[0][0]']
#
#  activation_24 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_28[0][0]']
#
#  activation_25 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_29[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 25, 25, 64)  192         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 25, 25, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 25, 25, 96)  288         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 25, 25, 96)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 12, 12, 384)  1152       ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 12, 12, 96)  288         ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 12, 12, 384)  0           ['batch_normalization_30[0][0]']
#
#  activation_29 (Activation)     (None, 12, 12, 96)   0           ['batch_normalization_33[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 12, 12, 128)  384        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 12, 12, 128)  384        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 12, 12, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 12, 12, 128)  384        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_35[0][0]']
#
#  activation_36 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 12, 12, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 12, 12, 128)  384        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_36[0][0]']
#
#  activation_37 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_41[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_34 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 12, 12, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 12, 12, 192)  576        ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 12, 12, 192)  576        ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 12, 12, 192)  576        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 12, 12, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_34[0][0]']
#
#  activation_33 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_37[0][0]']
#
#  activation_38 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_42[0][0]']
#
#  activation_39 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_43[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 12, 12, 160)  480        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 12, 12, 160)  480        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 12, 12, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 12, 12, 160)  480        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_45[0][0]']
#
#  activation_46 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 12, 12, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 12, 12, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_46[0][0]']
#
#  activation_47 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_51[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 12, 12, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 12, 12, 192)  576        ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 12, 12, 192)  576        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 12, 12, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_44[0][0]']
#
#  activation_43 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_47[0][0]']
#
#  activation_48 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_52[0][0]']
#
#  activation_49 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_53[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 12, 12, 160)  480        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 12, 12, 160)  480        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 12, 12, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 12, 12, 160)  480        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_55[0][0]']
#
#  activation_56 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 12, 12, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 12, 12, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  batch_normalization_61 (BatchN  (None, 12, 12, 160)  480        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_56[0][0]']
#
#  activation_57 (Activation)     (None, 12, 12, 160)  0           ['batch_normalization_61[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_54 (Conv2D)             (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 12, 12, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 12, 12, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 12, 12, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 12, 12, 192)  576        ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_62 (BatchN  (None, 12, 12, 192)  576        ['conv2d_62[0][0]']
#  ormalization)
#
#  batch_normalization_63 (BatchN  (None, 12, 12, 192)  576        ['conv2d_63[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_54[0][0]']
#
#  activation_53 (Activation)     (None, 12, 12, 192)  0           ['batch_normalization_57[0][0]']
#
# ...
#  batch_normalization_84 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_84[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 5, 5, 384)    1548288     ['activation_80[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  batch_normalization_85 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_81[0][0]']
#
#  activation_81 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_85[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_80 (Conv2D)             (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  batch_normalization_86 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_87 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  conv2d_88 (Conv2D)             (None, 5, 5, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 5, 5, 320)   960         ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_79 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_83[0][0]']
#
#  activation_82 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_83 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_87[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 5, 5, 192)   576         ['conv2d_88[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_80[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 5, 5, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_88[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 5, 5, 448)   1344        ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 5, 5, 448)    0           ['batch_normalization_93[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 5, 5, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_90[0][0]']
#
#  activation_90 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_94[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 5, 5, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_89 (Conv2D)             (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_95[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 5, 5, 384)   1152        ['conv2d_96[0][0]']
#  ormalization)
#
#  conv2d_97 (Conv2D)             (None, 5, 5, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 5, 5, 320)   960         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_88 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_92[0][0]']
#
#  activation_91 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_95[0][0]']
#
#  activation_92 (Activation)     (None, 5, 5, 384)    0           ['batch_normalization_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 5, 5, 192)   576         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 5, 5, 320)    0           ['batch_normalization_89[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5, 5, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 5, 5, 192)    0           ['batch_normalization_97[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  flatten (Flatten)              (None, 51200)        0           ['mixed10[0][0]']
#
#  dropout_1 (Dropout)            (None, 51200)        0           ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 2)            102402      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 21,905,186
# Trainable params: 102,402
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# https://www.analyticsvidhya.com/blog/2020/08/image-augmentation-on-the-fly-using-keras-imagedatagenerator/

# ImageDataGenerator class has the argument height_shift_range for a vertical shift of image and width_shift_range for a horizontal shift of image. 
# If the value is a float number, that would indicate the percentage of width or height of the image to shift. 
# Otherwise, if it is an integer value then simply the width or height are shifted by those many pixel values.

# ImageDataGenerator class allows you to randomly rotate images through any degree between 0 and 360 by providing an integer value in the rotation_range argument.
# When the image is rotated, some pixels will move outside the image and leave an empty area that needs to be filled in. 
# You can fill this in different ways like a constant value or nearest pixel values, etc. 
# This is specified in the fill_mode argument and the default value is “nearest” which simply replaces the empty area with the nearest pixel values.

# No Augmentation to the images

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %% [markdown]
# ### Training the model

# %%
# https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
# save the current model ( if better than previous) and go to next epoch and repeat until the end

from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-12-Inception-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 2.4324 - accuracy: 0.8298
# Epoch 00001: val_accuracy improved from -inf to 0.90476, saving model to Experiment-12-Inception-model-epoch-01-val-accuracy:-0.9048.h5
# 52/52 [==============================] - 21s 338ms/step - loss: 2.4324 - accuracy: 0.8298 - val_loss: 1.0982 - val_accuracy: 0.9048
# Epoch 2/30
# 53/52 [==============================] - ETA: 0s - loss: 0.5736 - accuracy: 0.9196
# Epoch 00002: val_accuracy did not improve from 0.90476
# 52/52 [==============================] - 16s 301ms/step - loss: 0.5736 - accuracy: 0.9196 - val_loss: 0.5909 - val_accuracy: 0.8952
# Epoch 3/30
# 53/52 [==============================] - ETA: 0s - loss: 0.5414 - accuracy: 0.9190
# Epoch 00003: val_accuracy improved from 0.90476 to 0.91190, saving model to Experiment-12-Inception-model-epoch-03-val-accuracy:-0.9119.h5
# 52/52 [==============================] - 16s 309ms/step - loss: 0.5414 - accuracy: 0.9190 - val_loss: 0.6975 - val_accuracy: 0.9119
# Epoch 4/30
# 53/52 [==============================] - ETA: 0s - loss: 0.
# Epoch 20/30
# 53/52 [==============================] - ETA: 0s - loss: 0.5668 - accuracy: 0.9452
# Epoch 00020: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 297ms/step - loss: 0.5668 - accuracy: 0.9452 - val_loss: 2.7238 - val_accuracy: 0.8762
# Epoch 21/30
# 53/52 [==============================] - ETA: 0s - loss: 0.8554 - accuracy: 0.9351
# Epoch 00021: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 296ms/step - loss: 0.8554 - accuracy: 0.9351 - val_loss: 1.1590 - val_accuracy: 0.9286
# Epoch 22/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4616 - accuracy: 0.9518
# Epoch 00022: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 299ms/step - loss: 0.4616 - accuracy: 0.9518 - val_loss: 0.5761 - val_accuracy: 0.9500
# Epoch 23/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4892 - accuracy: 0.9530
# Epoch 00023: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 297ms/step - loss: 0.4892 - accuracy: 0.9530 - val_loss: 0.4616 - val_accuracy: 0.9452
# Epoch 24/30
# 53/52 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.9458
# Epoch 00024: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 297ms/step - loss: 0.5940 - accuracy: 0.9458 - val_loss: 1.4203 - val_accuracy: 0.8786
# Epoch 25/30
# 53/52 [==============================] - ETA: 0s - loss: 1.0899 - accuracy: 0.9298
# Epoch 00025: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 298ms/step - loss: 1.0899 - accuracy: 0.9298 - val_loss: 1.1253 - val_accuracy: 0.9405
# Epoch 26/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7441 - accuracy: 0.9446
# Epoch 00026: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 299ms/step - loss: 0.7441 - accuracy: 0.9446 - val_loss: 0.8589 - val_accuracy: 0.9452
# Epoch 27/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4924 - accuracy: 0.9524
# Epoch 00027: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 298ms/step - loss: 0.4924 - accuracy: 0.9524 - val_loss: 2.0598 - val_accuracy: 0.8952
# Epoch 28/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6234 - accuracy: 0.9506
# Epoch 00028: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 297ms/step - loss: 0.6234 - accuracy: 0.9506 - val_loss: 0.7774 - val_accuracy: 0.9452
# Epoch 29/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.9613
# Epoch 00029: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 298ms/step - loss: 0.3422 - accuracy: 0.9613 - val_loss: 0.6435 - val_accuracy: 0.9381
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9726
# Epoch 00030: val_accuracy did not improve from 0.95238
# 52/52 [==============================] - 16s 297ms/step - loss: 0.2399 - accuracy: 0.9726 - val_loss: 0.7123 - val_accuracy: 0.9476

# %%
# Load best model for making prediction and plotting the statistics
# Edit the model name

model = load_model('Experiment-12-Inception-model-epoch-15-val-accuracy:-0.9524.h5')

# %% [markdown]
# ### Making the predictions

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

plt.figure(figsize=(6,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

plt.figure(figsize=(6,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       120
#            1       0.96      0.97      0.97       300
#
#     accuracy                           0.95       420
#    macro avg       0.94      0.94      0.94       420
# weighted avg       0.95      0.95      0.95       420

# %% [markdown]
# ## Variation #3
# ## Model #3 : VGG19
# ## Experiment #13

# %%
vggModel = VGG19(weights="imagenet", include_top=False,
input_tensor=Input(shape=(224, 224, 3)))

outputs = vggModel.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vggModel.input, outputs=outputs)

for layer in vggModel.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 4s 0us/step
# 80150528/80134624 [==============================] - 4s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout_2 (Dropout)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# https://www.analyticsvidhya.com/blog/2020/08/image-augmentation-on-the-fly-using-keras-imagedatagenerator/

# ImageDataGenerator class has the argument height_shift_range for a vertical shift of image and width_shift_range for a horizontal shift of image. 
# If the value is a float number, that would indicate the percentage of width or height of the image to shift. 
# Otherwise, if it is an integer value then simply the width or height are shifted by those many pixel values.

# ImageDataGenerator class allows you to randomly rotate images through any degree between 0 and 360 by providing an integer value in the rotation_range argument.
# When the image is rotated, some pixels will move outside the image and leave an empty area that needs to be filled in. 
# You can fill this in different ways like a constant value or nearest pixel values, etc. 
# This is specified in the fill_mode argument and the default value is “nearest” which simply replaces the empty area with the nearest pixel values.

# No Augmentation to the images

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

#
val_accuracy did not improve from 0.95952
# 52/52 [==============================] - 16s 309ms/step - loss: 0.1196 - accuracy: 0.9512 - val_loss: 0.2013 - val_accuracy: 0.9214
# Epoch 17/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9429
# Epoch 00017: val_accuracy did not improve from 0.95952
# 52/52 [==============================] - 16s 308ms/step - loss: 0.1553 - accuracy: 0.9429 - val_loss: 0.1466 - val_accuracy: 0.9548
# Epoch 18/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9512
# Epoch 00018: val_accuracy did not improve from 0.95952
# 52/52 [==============================] - 16s 306ms/step - loss: 0.1153 - accuracy: 0.9512 - val_loss: 0.1361 - val_accuracy: 0.9595
# Epoch 19/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9542
# Epoch 00019: val_accuracy did not improve from 0.95952
# 52/52 [==============================] - 16s 304ms/step - loss: 0.1124 - accuracy: 0.9542 - val_loss: 0.1148 - val_accuracy: 0.9571
# Epoch 20/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9589
# Epoch 00020: val_accuracy improved from 0.95952 to 0.96905, saving model to Experiment-13-VGG19-model-epoch-20-val-accuracy:-0.9690.h5
# 52/52 [==============================] - 16s 308ms/step - loss: 0.1070 - accuracy: 0.9589 - val_loss: 0.1194 - val_accuracy: 0.9690
# Epoch 21/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9554
# Epoch 00021: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 312ms/step - loss: 0.1146 - accuracy: 0.9554 - val_loss: 0.2430 - val_accuracy: 0.9238
# Epoch 22/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1036 - accuracy: 0.9607
# Epoch 00022: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 307ms/step - loss: 0.1036 - accuracy: 0.9607 - val_loss: 0.1520 - val_accuracy: 0.9429
# Epoch 23/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9595
# Epoch 00023: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 307ms/step - loss: 0.1186 - accuracy: 0.9595 - val_loss: 0.1331 - val_accuracy: 0.9524
# Epoch 24/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9512
# Epoch 00024: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 305ms/step - loss: 0.1263 - accuracy: 0.9512 - val_loss: 0.1126 - val_accuracy: 0.9619
# Epoch 25/30
# 53/52 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9631
# Epoch 00025: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 308ms/step - loss: 0.0942 - accuracy: 0.9631 - val_loss: 0.0961 - val_accuracy: 0.9667
# Epoch 26/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9506
# Epoch 00026: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 309ms/step - loss: 0.1197 - accuracy: 0.9506 - val_loss: 0.1620 - val_accuracy: 0.9429
# Epoch 27/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9649
# Epoch 00027: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 310ms/step - loss: 0.1073 - accuracy: 0.9649 - val_loss: 0.1074 - val_accuracy: 0.9690
# Epoch 28/30
# 53/52 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9690
# Epoch 00028: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 307ms/step - loss: 0.0848 - accuracy: 0.9690 - val_loss: 0.1105 - val_accuracy: 0.9619
# Epoch 29/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9423
# Epoch 00029: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 306ms/step - loss: 0.1504 - accuracy: 0.9423 - val_loss: 0.1122 - val_accuracy: 0.9643
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9583
# Epoch 00030: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 305ms/step - loss: 0.1082 - accuracy: 0.9583 - val_loss: 0.0985 - val_accuracy: 0.9667

# %%
# Load best model for making prediction and plotting the statistics
# Edit the model name

model = load_model('Experiment-13-VGG19-model-epoch-20-val-accuracy:-0.9690.h5')

# %% [markdown]
# ### Making the predictions

# %%
y_pred = model.predict(X_test, batch_size=batch_size)
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ### Plot statistics

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

plt.figure(figsize=(6,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

plt.figure(figsize=(6,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       120
#            1       0.99      0.97      0.98       300
#
#     accuracy                           0.97       420
#    macro avg       0.96      0.97      0.96       420
# weighted avg       0.97      0.97      0.97       420

# %% [markdown]
# ## Variation #3
# ## Model #4 : ResNet
# ## Experiment #14

# %%
res = ResNet50(weights="imagenet", include_top=False,input_tensor=Input(shape=(224, 224, 3)))

outputs = res.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=res.input, outputs=outputs)

for layer in res.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_4[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['conv5_block3_out[0][0]']
#
#  dropout_3 (Dropout)            (None, 100352)       0           ['flatten[0][0]']
#
#  dense_3 (Dense)                (None, 2)            200706      ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 23,788,418
# Trainable params: 200,706
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# https://www.analyticsvidhya.com/blog/2020/08/image-augmentation-on-the-fly-using-keras-imagedatagenerator/

# ImageDataGenerator class has the argument height_shift_range for a vertical shift of image and width_shift_range for a horizontal shift of image. 
# If the value is a float number, that would indicate the percentage of width or height of the image to shift. 
# Otherwise, if it is an integer value then simply the width or height are shifted by those many pixel values.

# ImageDataGenerator class allows you to randomly rotate images through any degree between 0 and 360 by providing an integer value in the rotation_range argument.
# When the image is rotated, some pixels will move outside the image and leave an empty area that needs to be filled in. 
# You can fill this in different ways like a constant value or nearest pixel values, etc. 
# This is specified in the fill_mode argument and the default value is “nearest” which simply replaces the empty area with the nearest pixel values.

# No Augmentation to the images

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %% [markdown]
# ### Training the Model

# %%
# https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
# save the current model ( if better than previous) and go to next epoch and repeat until the end

from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-14-ResNet-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 1.7497 - accuracy: 0.6661
# Epoch 00001: val_accuracy improved from -inf to 0.71429, saving model to Experiment-14-ResNet-model-epoch-01-val-accuracy:-0.7143.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 52/52 [==============================] - 20s 333ms/step - loss: 1.7497 - accuracy: 0.6661 - val_loss: 0.8641 - val_accuracy: 0.7143
# Epoch 2/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6512 - accuracy: 0.7435
# Epoch 00002: val_accuracy improved from 0.71429 to 0.81429, saving model to Experiment-14-ResNet-model-epoch-02-val-accuracy:-0.8143.h5
# 52/52 [==============================] - 16s 313ms/step - loss: 0.6512 - accuracy: 0.7435 - val_loss: 0.3877 - val_accuracy: 0.8143
# Epoch 3/30
# 53/52 [==============================] - ETA: 0s - loss: 0.5921 - accuracy: 0.7494
# Epoch 00003: val_accuracy did not improve from 0.81429
# 52/52 [==============================] - 16s 302ms/step - loss: 0.5921 - accuracy: 0.7494 - val_loss: 0.4153 - val_accuracy: 0.7976
# Epoch 4/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6162 - accuracy: 0.7589
# Epoch 00004: val_accuracy improved from 0.81429 to 0.82619, saving model to Experiment-14-ResNet-model-epoch-04-val-accuracy:-0.8262.h5
# 52/52 [==============================] - 16s 313ms/step - loss: 0.6162 - accuracy: 0.7589 - val_loss: 0.3789 - val_accuracy: 0.8262
# Epoch 5/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7433 - accuracy: 0.7452
# Epoch 00005: val_accuracy did not improve from 0.82619
# 52/52 [==============================] - 16s 305ms/step - loss: 0.7433 - accuracy: 0.7452 - val_loss: 1.5417 - val_accuracy: 0.7143
# Epoch 6/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.7518
# Epoch 00006: val_accuracy did not improve from 0.82619
# 52/52 [==============================] - 16s 299ms/step - loss: 0.7014 - accuracy: 0.7518 - val_loss: 0.4700 - val_accuracy: 0.7905
# Epoch 7/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.7685
# Epoch 00007: val_accuracy did not improve from 0.82619
# 52/52 [==============================] - 16s 303ms/step - loss: 0.6620 - accuracy: 0.7685 - val_loss: 0.4021 - val_accuracy: 0.8167
# Epoch 8/30
# 53/52 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7881
# Epoch 00008: val_accuracy did not improve from 0.82619
# 52/52 [==============================] - 16s 302ms/step - loss: 0.5454 - accuracy: 0.7881 - val_loss: 0.4023 - val_accuracy: 0.8143
# Epoch 9/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6810 - accuracy: 0.7619
# Epoch 00009: val_accuracy did not improve from 0.82619
# 52/52 [==============================] - 16s 301ms/step - loss: 0.6810 - accuracy: 0.7619 - val_loss: 0.6976 - val_accuracy: 0.7405
# Epoch 10/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7125 - accuracy: 0.7649
# Epoch 00010: val_accuracy did not improve from 0.82619
# 52/52 [==============================] - 16s 300ms/step - loss: 0.7125 - accuracy: 0.7649 - val_loss: 0.5541 - val_accuracy: 0.7786
# Epoch 11/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0
val_accuracy did not improve from 0.84524
# 52/52 [==============================] - 16s 298ms/step - loss: 0.6744 - accuracy: 0.7857 - val_loss: 0.5220 - val_accuracy: 0.8071
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.8460 - accuracy: 0.7655
# Epoch 00030: val_accuracy did not improve from 0.84524
# 52/52 [==============================] - 16s 300ms/step - loss: 0.8460 - accuracy: 0.7655 - val_loss: 1.3315 - val_accuracy: 0.7143

# %%
# Load best model for making prediction and plotting the statistics
# Edit the model name

model = load_model('Experiment-14-ResNet-model-epoch-12-val-accuracy:-0.8452.h5')

# %% [markdown]
# ### Making the Predictions

# %%
y_pred = model.predict(X_test, batch_size=batch_size)
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

plt.figure(figsize=(6,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

plt.figure(figsize=(6,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73       120
#            1       0.90      0.88      0.89       300
#
#     accuracy                           0.85       420
#    macro avg       0.81      0.82      0.81       420
# weighted avg       0.85      0.85      0.85       420

# %% [markdown]
# ## Variation # 04:
#
# 1. Class Imbalance : Yes ( Number of Covid images : 600 , Number of Non-Covid images : 1500 )
#
# 2. Image Augmentation : Yes
#
# 3. Noise Removal from images : Yes

# %%
# Preparing Labels
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

count_orig_covid_img_for_model = 600
count_normal_img_for_model = 1500

# %%
for i in range(count_orig_covid_img_for_model):
  #if i%10==0:
    #print('i:',i)
  image = cv2.imread(covid_files[i])
  image = cv2.GaussianBlur(image, (9, 9),0) # Remove Gaussian Noise
  image = cv2.medianBlur(image, 9) # Remove Median Noise
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  covid_images.append(image)
  covid_labels.append('COVID')

  # Normal Images
for j in range(count_normal_img_for_model): 
  #if j%10==0:
    #print('j:',j)
  image = cv2.imread(noncovid_files[j])
  image = cv2.GaussianBlur(image, (9, 9),0) # Remove Gaussian Noise
  image = cv2.medianBlur(image, 9) # Remove Median Noise
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('NonCOVID')

# %%
# Plot Images
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()

# %%
# Normalization
# Model takes images in the form of array of pixels. Hence convert into array and normalize
# normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# %%
# split into training and testing

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# ## Variation #4
# ## Model #1 : Xception
# ## Experiment #16

# %%
xception = Xception(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = xception.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=xception.input, outputs=outputs)

for layer in xception.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_6[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_98 (Conv2D)             (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 55, 55, 128)  512        ['conv2d_98[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_98[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add_12[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_99 (Conv2D)             (None, 28, 28, 256)  32768       ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_99[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_99[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_13[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 728)  186368      ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_100 (Batch  (None, 14, 14, 728)  2912       ['conv2d_100[0][0]']
#  Normalization)
#
#  add_14 (Add)                   (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_100[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_14[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_15 (Add)                   (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_14[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_15[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_16 (Add)                   (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_15[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_16[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_17 (Add)                   (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_16[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_17[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_18 (Add)                   (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_17[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_18[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_19 (Add)                   (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_18[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_19[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_20 (Add)                   (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_19[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_20[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_21 (Add)                   (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_20[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_21[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_22 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_21[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_22[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_101 (Conv2D)            (None, 7, 7, 1024)   745472      ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_101 (Batch  (None, 7, 7, 1024)  4096        ['conv2d_101[0][0]']
#  Normalization)
#
#  add_23 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_101[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_23[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  flatten (Flatten)              (None, 100352)       0           ['block14_sepconv2_act[0][0]']
#
#  dropout_5 (Dropout)            (None, 100352)       0           ['flatten[0][0]']
#
#  dense_5 (Dense)                (None, 2)            200706      ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 21,062,186
# Trainable params: 200,706
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %%
# Adjust the parameters of image augmentation 

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
### Training the model
# https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
# save the current model ( if better than previous) and go to next epoch and repeat until the end

from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-16-Xception-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.8696
# Epoch 00001: val_accuracy improved from -inf to 0.89048, saving model to Experiment-16-Xception-model-epoch-01-val-accuracy:-0.8905.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
#
# Epoch 20/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3970 - accuracy: 0.9488
# Epoch 00020: val_accuracy improved from 0.93095 to 0.93571, saving model to Experiment-16-Xception-model-epoch-20-val-accuracy:-0.9357.h5
# 52/52 [==============================] - 17s 317ms/step - loss: 0.3970 - accuracy: 0.9488 - val_loss: 0.7246 - val_accuracy: 0.9357
# Epoch 21/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.9518
# Epoch 00021: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 312ms/step - loss: 0.3878 - accuracy: 0.9518 - val_loss: 0.7989 - val_accuracy: 0.9071
# Epoch 22/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.9631
# Epoch 00022: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 308ms/step - loss: 0.2433 - accuracy: 0.9631 - val_loss: 0.9223 - val_accuracy: 0.9357
# Epoch 23/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.9661
# Epoch 00023: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 310ms/step - loss: 0.2640 - accuracy: 0.9661 - val_loss: 1.7314 - val_accuracy: 0.8214
# Epoch 24/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3144 - accuracy: 0.9667
# Epoch 00024: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 305ms/step - loss: 0.3144 - accuracy: 0.9667 - val_loss: 0.9100 - val_accuracy: 0.9238
# Epoch 25/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9696
# Epoch 00025: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 308ms/step - loss: 0.2167 - accuracy: 0.9696 - val_loss: 0.8117 - val_accuracy: 0.9286
# Epoch 26/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9732
# Epoch 00026: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 309ms/step - loss: 0.1753 - accuracy: 0.9732 - val_loss: 1.0052 - val_accuracy: 0.9238
# Epoch 27/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9702
# Epoch 00027: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 307ms/step - loss: 0.1806 - accuracy: 0.9702 - val_loss: 0.8760 - val_accuracy: 0.9310
# Epoch 28/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9726
# Epoch 00028: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 304ms/step - loss: 0.2010 - accuracy: 0.9726 - val_loss: 0.8386 - val_accuracy: 0.9190
# Epoch 29/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.9631
# Epoch 00029: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 307ms/step - loss: 0.1968 - accuracy: 0.9631 - val_loss: 1.0454 - val_accuracy: 0.9143
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4202 - accuracy: 0.9542
# Epoch 00030: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 306ms/step - loss: 0.4202 - accuracy: 0.9542 - val_loss: 0.9655 - val_accuracy: 0.9286

# %%
### Load best model for making prediction and plotting the statistics
model = load_model('Experiment-16-Xception-model-epoch-20-val-accuracy:-0.9357.h5')

# Make Predictions
y_pred = model.predict(X_test, batch_size=batch_size)

# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
# Plot Statistics
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve - Experiment')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

# Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

# Accuracy and Loss Plots
plt.figure(figsize=(6,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()


plt.figure(figsize=(6,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       120
#            1       0.96      0.95      0.95       300
#
#     accuracy                           0.94       420
#    macro avg       0.92      0.92      0.92       420
# weighted avg       0.94      0.94      0.94       420

# %% [markdown]
# ## Variation #4
# ## Model #2 : InceptionV3
# ## Experiment #17

# %%
inception = InceptionV3(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = inception.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=inception.input, outputs=outputs)

for layer in inception.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_102 (Conv2D)            (None, 111, 111, 32  864         ['input_7[0][0]']
#                                 )
#
#  batch_normalization_102 (Batch  (None, 111, 111, 32  96         ['conv2d_102[0][0]']
#  Normalization)                 )
#
#  activation_94 (Activation)     (None, 111, 111, 32  0           ['batch_normalization_102[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 109, 109, 32  9216        ['activation_94[0][0]']
#                                 )
#
#  batch_normalization_103 (Batch  (None, 109, 109, 32  96         ['conv2d_103[0][0]']
#  Normalization)                 )
#
#  activation_95 (Activation)     (None, 109, 109, 32  0           ['batch_normalization_103[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 109, 109, 64  18432       ['activation_95[0][0]']
#                                 )
#
#  batch_normalization_104 (Batch  (None, 109, 109, 64  192        ['conv2d_104[0][0]']
#  Normalization)                 )
#
#  activation_96 (Activation)     (None, 109, 109, 64  0           ['batch_normalization_104[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 54, 54, 64)  0           ['activation_96[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_105 (Batch  (None, 54, 54, 80)  240         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_97 (Activation)     (None, 54, 54, 80)   0           ['batch_normalization_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_106 (Batch  (None, 52, 52, 192)  576        ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_98 (Activation)     (None, 52, 52, 192)  0           ['batch_normalization_106[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_98[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_110 (Batch  (None, 25, 25, 64)  192         ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_110[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_108 (Batch  (None, 25, 25, 48)  144         ['conv2d_108[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 25, 25, 96)  288         ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_108[0][0]']
#
#  activation_103 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_111[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 25, 25, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_107 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_107 (Batch  (None, 25, 25, 64)  192         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_109 (Batch  (None, 25, 25, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 25, 25, 96)  288         ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_113 (Batch  (None, 25, 25, 32)  96          ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_107[0][0]']
#
#  activation_101 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_109[0][0]']
#
#  activation_104 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_112[0][0]']
#
#  activation_105 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_113[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_117 (Batch  (None, 25, 25, 64)  192         ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_117[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_115 (Batch  (None, 25, 25, 48)  144         ['conv2d_115[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 25, 25, 96)  288         ['conv2d_118[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_115[0][0]']
#
#  activation_110 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_118[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_114 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_114 (Batch  (None, 25, 25, 64)  192         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 25, 25, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 25, 25, 96)  288         ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_120 (Batch  (None, 25, 25, 64)  192         ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_114[0][0]']
#
#  activation_108 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_116[0][0]']
#
#  activation_111 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_119[0][0]']
#
#  activation_112 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_120[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_124 (Batch  (None, 25, 25, 64)  192         ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_124[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_122 (Batch  (None, 25, 25, 48)  144         ['conv2d_122[0][0]']
#  Normalization)
#
#  batch_normalization_125 (Batch  (None, 25, 25, 96)  288         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_122[0][0]']
#
#  activation_117 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_125[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_121 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_121 (Batch  (None, 25, 25, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 25, 25, 64)  192         ['conv2d_123[0][0]']
#  Normalization)
#
#  batch_normalization_126 (Batch  (None, 25, 25, 96)  288         ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 25, 25, 64)  192         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_121[0][0]']
#
#  activation_115 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_123[0][0]']
#
#  activation_118 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_126[0][0]']
#
#  activation_119 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_127[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_129 (Batch  (None, 25, 25, 64)  192         ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_129[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_130 (Batch  (None, 25, 25, 96)  288         ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_130[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_122[0][0]']
#
#  batch_normalization_128 (Batch  (None, 12, 12, 384)  1152       ['conv2d_128[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 12, 12, 96)  288         ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_128[0][0]']
#
#  activation_123 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_131[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_136 (Batch  (None, 12, 12, 128)  384        ['conv2d_136[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_128[0][0]']
#
#  batch_normalization_137 (Batch  (None, 12, 12, 128)  384        ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_129[0][0]']
#
#  batch_normalization_133 (Batch  (None, 12, 12, 128)  384        ['conv2d_133[0][0]']
#  Normalization)
#
#  batch_normalization_138 (Batch  (None, 12, 12, 128)  384        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_133[0][0]']
#
#  activation_130 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_125[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_130[0][0]']
#
#  batch_normalization_134 (Batch  (None, 12, 12, 128)  384        ['conv2d_134[0][0]']
#  Normalization)
#
#  batch_normalization_139 (Batch  (None, 12, 12, 128)  384        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_134[0][0]']
#
#  activation_131 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_139[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_132 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_126[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_131[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_132 (Batch  (None, 12, 12, 192)  576        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_135 (Batch  (None, 12, 12, 192)  576        ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 12, 12, 192)  576        ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 12, 12, 192)  576        ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_132[0][0]']
#
#  activation_127 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_135[0][0]']
#
#  activation_132 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_140[0][0]']
#
#  activation_133 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_141[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_146 (Batch  (None, 12, 12, 160)  480        ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_138[0][0]']
#
#  batch_normalization_147 (Batch  (None, 12, 12, 160)  480        ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_139[0][0]']
#
#  batch_normalization_143 (Batch  (None, 12, 12, 160)  480        ['conv2d_143[0][0]']
#  Normalization)
#
#  batch_normalization_148 (Batch  (None, 12, 12, 160)  480        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_143[0][0]']
#
#  activation_140 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_135[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_140[0][0]']
#
#  batch_normalization_144 (Batch  (None, 12, 12, 160)  480        ['conv2d_144[0][0]']
#  Normalization)
#
#  batch_normalization_149 (Batch  (None, 12, 12, 160)  480        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_144[0][0]']
#
#  activation_141 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_149[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_142 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_136[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_141[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_142 (Batch  (None, 12, 12, 192)  576        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 12, 12, 192)  576        ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 12, 12, 192)  576        ['conv2d_150[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 12, 12, 192)  576        ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_142[0][0]']
#
#  activation_137 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_145[0][0]']
#
#  activation_142 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_150[0][0]']
#
#  activation_143 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_151[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_156 (Batch  (None, 12, 12, 160)  480        ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_156[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_148[0][0]']
#
#  batch_normalization_157 (Batch  (None, 12, 12, 160)  480        ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_157[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_149[0][0]']
#
#  batch_normalization_153 (Batch  (None, 12, 12, 160)  480        ['conv2d_153[0][0]']
#  Normalization)
#
#  batch_normalization_158 (Batch  (None, 12, 12, 160)  480        ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_153[0][0]']
#
#  activation_150 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_158[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_145[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_150[0][0]']
#
#  batch_normalization_154 (Batch  (None, 12, 12, 160)  480        ['conv2d_154[0][0]']
#  Normalization)
#
#  batch_normalization_159 (Batch  (None, 12, 12, 160)  480        ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_154[0][0]']
#
#  activation_151 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_159[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_152 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_146[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_151[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_152 (Batch  (None, 12, 12, 192)  576        ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_155 (Batch  (None, 12, 12, 192)  576        ['conv2d_155[0][0]']
#  Normalization)
#
#  batch_normalization_160 (Batch  (None, 12, 12, 192)  576        ['conv2d_160[0][0]']
#  Normalization)
#
#  batch_normalization_161 (Batch  (None, 12, 12, 192)  576        ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_152[0][0]']
#
#  activation_147 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_155[0][0]']
#
#  activation_152 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_160[0][0]']
#
#  activation_153 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_161[0][0]']
# ...
#  batch_normalization_182 (Batch  (None, 5, 5, 448)   1344        ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_174 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_182[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_174[0][0]']
#
#  batch_normalization_179 (Batch  (None, 5, 5, 384)   1152        ['conv2d_179[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 5, 5, 384)   1152        ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_179[0][0]']
#
#  activation_175 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_175[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_178 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_180 (Batch  (None, 5, 5, 384)   1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  batch_normalization_181 (Batch  (None, 5, 5, 384)   1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 5, 5, 384)   1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 5, 5, 384)   1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  conv2d_186 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_178 (Batch  (None, 5, 5, 320)   960         ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_173 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_181[0][0]']
#
#  activation_176 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_184[0][0]']
#
#  activation_177 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_185[0][0]']
#
#  batch_normalization_186 (Batch  (None, 5, 5, 192)   576         ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_178[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 5, 5, 768)    0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_186[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_191 (Batch  (None, 5, 5, 448)   1344        ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_191[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_183[0][0]']
#
#  batch_normalization_188 (Batch  (None, 5, 5, 384)   1152        ['conv2d_188[0][0]']
#  Normalization)
#
#  batch_normalization_192 (Batch  (None, 5, 5, 384)   1152        ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_188[0][0]']
#
#  activation_184 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_184[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_187 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_189 (Batch  (None, 5, 5, 384)   1152        ['conv2d_189[0][0]']
#  Normalization)
#
#  batch_normalization_190 (Batch  (None, 5, 5, 384)   1152        ['conv2d_190[0][0]']
#  Normalization)
#
#  batch_normalization_193 (Batch  (None, 5, 5, 384)   1152        ['conv2d_193[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 5, 5, 384)   1152        ['conv2d_194[0][0]']
#  Normalization)
#
#  conv2d_195 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_187 (Batch  (None, 5, 5, 320)   960         ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_189[0][0]']
#
#  activation_182 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_190[0][0]']
#
#  activation_185 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_193[0][0]']
#
#  activation_186 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_194[0][0]']
#
#  batch_normalization_195 (Batch  (None, 5, 5, 192)   576         ['conv2d_195[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_187[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 5, 5, 768)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_195[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
#  flatten (Flatten)              (None, 51200)        0           ['mixed10[0][0]']
#
#  dropout_6 (Dropout)            (None, 51200)        0           ['flatten[0][0]']
#
#  dense_6 (Dense)                (None, 2)            102402      ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 21,905,186
# Trainable params: 102,402
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# Adjust the parameters of image augmentation 

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
# Train the model
from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-17-Inception-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 1.0329 - accuracy: 0.8518
# Epoch 00001: val_accuracy improved from -inf to 0.92143, saving model to Experiment-17-Inception-model-epoch-01-val-accuracy:-0.9214.h5
# 52/52 [==============================] - 21s 338ms/step - loss: 1.0329 - accuracy: 0.8518 - val_loss: 0.6868 - val_accuracy: 0.9214
# Epoch 2/30
# 53/52 [==============================] - ETA: 0s - loss: 0.8496 - accuracy: 0.8940
# Epoch 00002: val_accuracy did not improve from 0.92143
# 52/52 [==============================] - 16s
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91       120
#            1       0.96      0.97      0.96       300
#
#     accuracy                           0.95       420
#    macro avg       0.94      0.93      0.94       420
# weighted avg       0.95      0.95      0.95       420

# %% [markdown]
# ## Variation #4
# ## Model #3 : VGG19
# ## Experiment #18

# %%
vggModel = VGG19(weights="imagenet", include_top=False,
input_tensor=Input(shape=(224, 224, 3)))

outputs = vggModel.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vggModel.input, outputs=outputs)

for layer in vggModel.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout_7 (Dropout)         (None, 25088)             0
#
#  dense_7 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Adjust the parameters of image augmentation 

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %% [markdown]
# Training the model

# %%
# https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
# save the current model ( if better than previous) and go to next epoch and repeat until the end

from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-18-vgg-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 0.4397 - accuracy: 0.8161
# Epoch 00001: val_accuracy improved from -inf to 0.90000, saving model to Experiment-18-vgg-model-epoch-01-val-accuracy:-0.9000.h5
# 52/52 [==============================] - 18s 323ms/step - loss: 0.4397 - accuracy: 0.8161 - val_loss: 0.2596 - val_accuracy: 0.9000
# Epoch 2/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2965 - accuracy: 0.8655
# Epoch 00002: val_accuracy did not improve from 0.90000
# 52/52 [==============================] - 17s 314ms/step - loss: 0.2965 - accuracy: 0.8655 - val_loss: 0.2846 - val_accuracy: 0.8690
# Epoch 3/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.8821
# Epoch 00003: val_accuracy improved from 0.90000 to 0.92381, saving model to Experiment-18-vgg-model-epoch-03-val-accuracy:-0.9238.h5
# 52/52 [==============================] - 16s 308ms/step - loss: 0.2583 - accuracy: 0.8821 - val_loss: 0.1930 - val_accuracy: 0.9238
# Epoch 4/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.8905
# Epoch 00004: val_accuracy improved from 0.92381 to 0.92619, saving model to Experiment-18-vgg-model-epoch-04-val-accuracy:-0.9262.h5
# 52/52 [==============================] - 17s 313ms/step - loss: 0.2578 - accuracy: 0.8905 - val_loss: 0.1861 - val_accuracy: 0.9262
# Epoch 5/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2564 - accuracy: 0.8851
# Epoch 00005: val_accuracy improved from 0.92619 to 0.93571, saving model to Experiment-18-vgg-model-epoch-05-val-accuracy:-0.9357.h5
# 52/52 [==============================] - 17s 317ms/step - loss: 0.2564 - accuracy: 0.8851 - val_loss: 0.1652 - val_accuracy: 0.9357
# Epoch 6/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2770 - accuracy: 0.8899
# Epoch 00006: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 311ms/step - loss: 0.2770 - accuracy: 0.8899 - val_loss: 0.3293 - val_accuracy: 0.8524
# Epoch 7/30
# 53/52 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8738
# Epoch 00007: val_accuracy did not improve from 0.93571
# 52/52 [==============================] - 16s 305ms/step - loss: 0.3269 - accuracy: 0.8738 - val_loss: 0.1946 - val_accuracy: 0.9190
# Epoch 8/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9071
# Epoch 00008: val_accuracy improved from 0.93571 to 0.94524, saving model to Experiment-18-vgg-model-epoch-08-val-accuracy:-0.9452.h5
# 52/52 [==============================] - 16s 312ms/step - loss: 0.2222 - accuracy: 0.9071 - val_loss: 0.1528 - val_accuracy: 0.9452
# Epoch 9/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9060
# Epoch 00009: val_accuracy did not improve from 0.94524
# 52/52 [==============================] - 16s 311ms/step - loss: 0.2238 - accuracy: 0.9060 - val_loss: 0.2387 - val_accuracy: 0.9000
# Epoch 10/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9089
# Epoch 00010: val_accuracy did not improve from 0.94524
# 52/52 [==============================] - 16s 307ms/step - loss: 0.2170 - accuracy: 0.9089 - val_loss: 0.2986 - val_accuracy: 0.8881
# Epoch 11/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9149
# Epoch 00011: val_accuracy improved from 0.94524 to 0.95714, saving model to Experiment-18-vgg-model-epoch-11-val-accuracy:-0.9571.h5
# 52/52 [==============================] - 16s 310ms/step - loss: 0.1960 - accuracy: 0.9149 - val_loss: 0.1339 - val_accuracy: 0.9571
# Epoch 12/30
# 53/52 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9375
# Epoch 00030: val_accuracy did not improve from 0.96905
# 52/52 [==============================] - 16s 309ms/step - loss: 0.1551 - accuracy: 0.9375 - val_loss: 0.1314 - val_accuracy: 0.9548

# %%
#Load best model for making prediction and plotting the statistics
model = load_model('Experiment-18-vgg-model-epoch-29-val-accuracy:-0.9690.h5')

# %%
# Making Predicions

y_pred = model.predict(X_test, batch_size=batch_size)

# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
# Plot ROC Curve

fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
#Plot Confusion Matrix

def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

# Classification Report

from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

## Accuracy and Loss Plots

plt.figure(figsize=(6,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

plt.figure(figsize=(6,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       120
#            1       0.99      0.97      0.98       300
#
#     accuracy                           0.97       420
#    macro avg       0.96      0.97      0.96       420
# weighted avg       0.97      0.97      0.97       420

# %% [markdown]
# ## Variation #4
# ## Model #4 : ResNet
# ## Experiment #19

# %%
res = ResNet50(weights="imagenet", include_top=False,input_tensor=Input(shape=(224, 224, 3)))

outputs = res.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=res.input, outputs=outputs)

for layer in res.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_9[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['conv5_block3_out[0][0]']
#
#  dropout_8 (Dropout)            (None, 100352)       0           ['flatten[0][0]']
#
#  dense_8 (Dense)                (None, 2)            200706      ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 23,788,418
# Trainable params: 200,706
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# Adjust the parameters of image augmentation 

train_aug = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %%
# Training the Model

# https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
# save the current model ( if better than previous) and go to next epoch and repeat until the end

from keras.callbacks import ModelCheckpoint
# checkpoint
filepath="Experiment-19-ResNet-model-epoch-{epoch:02d}-val-accuracy:-{val_accuracy:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    callbacks=callbacks_list,
                    verbose=1,
                    epochs=30)
# Out:
# Epoch 1/30
# 53/52 [==============================] - ETA: 0s - loss: 1.5378 - accuracy: 0.6494
# Epoch 00001: val_accuracy improved from -inf to 0.71429, saving model to Experiment-19-ResNet-model-epoch-01-val-accuracy:-0.7143.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 52/52 [==============================] - 20s 336ms/step - loss: 1.5378 - accuracy: 0.6494 - val_loss: 1.4402 - val_accuracy: 0.7143
# Epoch 2/30
# 53/52 [==============================] - ETA: 0s - loss: 0.8259 - accuracy: 0.7137
# Epoch 00002: val_accuracy improved from 0.71429 to 0.71667, saving model to Experiment-19-ResNet-model-epoch-02-val-accuracy:-0.7167.h5
# 52/52 [==============================] - 17s 315ms/step - loss: 0.8259 - accuracy: 0.7137 - val_loss: 0.6962 - val_accuracy: 0.7167
# Epoch 3/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.7452
# Epoch 00003: val_accuracy improved from 0.71667 to 0.74048, saving model to Experiment-19-ResNet-model-epoch-03-val-accuracy:-0.7405.h5
# 52/52 [==============================] - 17s 318ms/step - loss: 0.6626 - accuracy: 0.7452 - val_loss: 0.5495 - val_accuracy: 0.7405
# Epoch 4/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.7387
# Epoch 00004: val_accuracy did not improve from 0.74048
# 52/52 [==============================] - 16s 302ms/step - loss: 0.6713 - accuracy: 0.7387 - val_loss: 0.6849 - val_accuracy: 0.6952
# Epoch 5/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7454 - accuracy: 0.7298
# Epoch 00005: val_accuracy did not improve from 0.74048
# 52/52 [==============================] - 16s 303ms/step - loss: 0.7454 - accuracy: 0.7298 - val_loss: 0.6114 - val_accuracy: 0.7167
# Epoch 6/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6192 - accuracy: 0
val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 304ms/step - loss: 0.8353 - accuracy: 0.7536 - val_loss: 0.7881 - val_accuracy: 0.7405
# Epoch 21/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7245 - accuracy: 0.7810
# Epoch 00021: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 302ms/step - loss: 0.7245 - accuracy: 0.7810 - val_loss: 0.4306 - val_accuracy: 0.8357
# Epoch 22/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6989 - accuracy: 0.7625
# Epoch 00022: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 301ms/step - loss: 0.6989 - accuracy: 0.7625 - val_loss: 0.6818 - val_accuracy: 0.7500
# Epoch 23/30
# 53/52 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.7798
# Epoch 00023: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 300ms/step - loss: 0.6198 - accuracy: 0.7798 - val_loss: 0.6867 - val_accuracy: 0.7429
# Epoch 24/30
# 53/52 [==============================] - ETA: 0s - loss: 0.8066 - accuracy: 0.7482
# Epoch 00024: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 301ms/step - loss: 0.8066 - accuracy: 0.7482 - val_loss: 0.4640 - val_accuracy: 0.8119
# Epoch 25/30
# 53/52 [==============================] - ETA: 0s - loss: 1.0808 - accuracy: 0.7262
# Epoch 00025: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 302ms/step - loss: 1.0808 - accuracy: 0.7262 - val_loss: 0.4971 - val_accuracy: 0.8214
# Epoch 26/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.7810
# Epoch 00026: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 305ms/step - loss: 0.7046 - accuracy: 0.7810 - val_loss: 0.4368 - val_accuracy: 0.8357
# Epoch 27/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7201 - accuracy: 0.7792
# Epoch 00027: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 301ms/step - loss: 0.7201 - accuracy: 0.7792 - val_loss: 0.6355 - val_accuracy: 0.7619
# Epoch 28/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7288 - accuracy: 0.7542
# Epoch 00028: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 299ms/step - loss: 0.7288 - accuracy: 0.7542 - val_loss: 1.2255 - val_accuracy: 0.7167
# Epoch 29/30
# 53/52 [==============================] - ETA: 0s - loss: 0.8493 - accuracy: 0.7565
# Epoch 00029: val_accuracy did not improve from 0.83571
# 52/52 [==============================] - 16s 303ms/step - loss: 0.8493 - accuracy: 0.7565 - val_loss: 0.5131 - val_accuracy: 0.7976
# Epoch 30/30
# 53/52 [==============================] - ETA: 0s - loss: 0.7415 - accuracy: 0.7774
# Epoch 00030: val_accuracy improved from 0.83571 to 0.84524, saving model to Experiment-19-ResNet-model-epoch-30-val-accuracy:-0.8452.h5
# 52/52 [==============================] - 17s 317ms/step - loss: 0.7415 - accuracy: 0.7774 - val_loss: 0.4102 - val_accuracy: 0.8452

# %%
# Load best model for making prediction and plotting the statistics

model = load_model('Experiment-19-ResNet-model-epoch-30-val-accuracy:-0.8452.h5')

# %%
### Making Predicions

y_pred = model.predict(X_test, batch_size=batch_size)

# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
### Plot ROC Curve

fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %%
### Plot Confusion Matrix

def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='Blues',annot=True, fmt='g')
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  if normalize:
    plt.title('Confusion Matrix with normalization')
  else:
    plt.title('Confusion Matrix without normalization')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

plot_confusion_matrix(normalize=None)
print('----------------------------------------------')
plot_confusion_matrix(normalize='true')

# Classification Report

from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))

# Accuracy and Loss Plots

plt.figure(figsize=(6,6))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

plt.figure(figsize=(6,6))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
# Out:
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73       120
#            1       0.89      0.89      0.89       300
#
#     accuracy                           0.85       420
#    macro avg       0.81      0.81      0.81       420
# weighted avg       0.84      0.85      0.85       420
